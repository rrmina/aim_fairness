# %%
import numpy as np
import matplotlib.pyplot as plt

def readpgm(name):
    with open(name) as f:
        lines = f.readlines()
        
    # Ignore the command lines
    for l in list(lines):
        if l[0] == '#':
            lines.remove(l)
            
        # Make sure it is ASCII format (P2)
        assert lines[0].strip() == 'P2'
        
        # Converts data to a list of integers
        data = []
        for line in lines[1:]:
            data.extend( [int(c) for c in line.split()] )
            
    return (np.array(data[3:]),(data[1],data[0]),data[2])
    
data = readpgm('pgm1.pgm')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-988ec78fa4bc> in <module>
#      21     return (np.array(data[3:]),(data[1],data[0]),data[2])
#      22
# ---> 23 data = readpgm('pgm1.pgm')
#
# <ipython-input-6-988ec78fa4bc> in readpgm(name)
#       4 def readpgm(name):
#       5     with open(name) as f:
# ----> 6         lines = f.readlines()
#       7
#       8     # Ignore the command lines
#
# c:\users\rusty\appdata\local\programs\python\python37\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# ...

# %%
import numpy as np

with open('pgm1.pgm', 'r', encoding='cp850') as infile:
    header = infile.readline()
    print(header)
    
    width, height, maxval = [int(item) for item in header.split()[1:]]
    image = np.fromfile(infile, dtype=np.uint16).reshape((height, width))
# Out:
# P5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-56f996972927> in <module>
#       5     print(header)
#       6
# ----> 7     width, height, maxval = [int(item) for item in header.split()[1:]]
#       8     image = np.fromfile(infile, dtype=np.uint16).reshape((height, width))
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %%
with open('pgm1.pgm', 'rb') as fp:
    line = fp.readline()
    count = 1
    while line:
        print("Line {}: {}".format(count, line))
        print(len(line))
        line = fp.readline()
        count += 1
# Out:
# Line 1: b'P5\n'
# 3
# Line 2: b'#@DOME@ xc73 yaleB11_P00 000 01 Ambient\n'
# 40
# Line 3: b'640 480\n'
# 8
# Line 4: b'255\n'
# 4
# ...

# %%
from PIL import Image, ImageFile
img = Image.open("pgm1.pgm").convert('LA')
img.save("hello.png")

# %%
print(img)
# Out:
# <PIL.Image.Image image mode=LA size=640x480 at 0x1DD2915F508>

# %%
img.show()

# %%
ok = plt.imread("hello.png")
ok.shape
# Out:
# (480, 640, 4)

# %%
I = np.asarray(Image.open('pgm1.pgm'))

# %%
I.shape
# Out:
# (480, 640)

# %%
I
# Out:
# array([[182, 180, 181, ...,   7,   4,   6],
#        [180, 179, 176, ...,   5,   5,   5],
#        [174, 177, 176, ...,   6,   6,   5],
#        ...,
#        [ 22,  30,  34, ...,   3,   3,   3],
#        [ 19,  25,  28, ...,   4,   2,   2],
#        [ 16,  21,  23, ...,   3,   3,   3]], dtype=uint8)

# %%
name = "hello.pgm"

print(name[-4:] == ".pgm")
# Out:
# True

# %%
ook = ['torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 
168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 
'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 
192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 
1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'tor8])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch. 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 1ch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', ', 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.S168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 19h.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 't 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168][1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Si68])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'to192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Siz8])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192,Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'tor92, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, ize([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torc2, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1,orch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size()', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 1ze([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])']
# Out:
#   File "<ipython-input-36-b3751dcdd39d>", line 1
#     ook = ['torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1, 192, 168])', 'torch.Size([1, 1,
# ...

# %%
import extYaleB

# %%
DATASET_PATH = "data/"
DATASET_FOLDER = "CroppedYale"

from torchvision import transforms
import torch

# Dataset and Dataloader
transform = transforms.Compose([
    transforms.ToTensor()
])
dataset = extYaleB.PGMDataset(DATASET_PATH, download=True, transform=transform)
BATCH_SIZE = 1
dataloader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

aye = []
for images, labels in dataloader:
    # curr_batch_size = images.shape[0]
    aye.append(str(images.shape))

# %%
len(aye)
# Out:
# 2452

# %%
list(set(aye))
# Out:
# ['torch.Size([1, 1, 480, 640])', 'torch.Size([1, 1, 192, 168])']
